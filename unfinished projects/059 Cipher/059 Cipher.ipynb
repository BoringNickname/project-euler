# %%
import numpy as np
alpha = "".join(chr(x) for x in range(128))

# %%
print(alpha[65])
# Out:
# A

# %%
data = np.genfromtxt('p059_cipher.txt', delimiter = ',')
i = 0
text = []
while i < len(data):
    print(alpha[int(data[i])])
    text.append(alpha[int(data[i])])
    i += 1
# Out:
# $
#
# P
#
#
#
#
#
#
#
# X
#
#
#
#
#
# X
#
#
#
#
# E
#
#
#
# X
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# P
#
#
#
# P
#
#
#
#
# E
#
#
# E
# =
#
#
#
#
# B
#
# P
#
#
#
#
# X
#
#
#
#
#
#
#
#
#
#
#
# E
#
#
#
#
#
#
# T
# P
# G
# <
#
# E
#
#
#
#
#
#
# X
#
#
#
#
#
#
#
#
#
#
# X
#
#
#
#
#
#
#
#
#
#
#
#
#
# R
# E
# #
# ?
#
# X
#
#
#
# P
#
#
#
#
# X
#
#
# X
#
#
#
#
#
#
#
# P
#
#
#
# P
#
#
#
#
#
#
#
#
#
#
#
#
# -
# _
# X
# 9
# E
#
#
#
#
# P
#
#
#
#
#
#
#
#
# P
#
#
#
#
#
# \
# E
#
#
#
#
#
# E
#
#
#
#
#
#
#
#
#
#
#
#
# T
# P
#
#
# P
#
#
#
#
#
#
#
# X
#
#
#
#
#
#
#
#
#
#
# E
#
#
#
# X
#
#
#
# P
#
#
#
#
#
#
#
# E
#
#
#
# X
#
#
# X
#
#
#
#
# E
#
#
#
#
#
#
# X
# A
# E
# S
# P
# T
# W
# D
# E
# S
# P
# T
# W
# I
# E
# S
# P
# T
# W
# A
# S
# X
# [
# E
#
#
#
# V
# \
# E
#
#
#
#
#
# E
#
#
#
#
#
#
#
# P
#
#
#
# P
#
#
#
# E
#
#
#
#
#
#
#
#
#
#
# P
#
#
#
# P
#
#
#
# E
#
#
#
#
#
#
# T
# P
#
#
# P
#
#
#
#
# X
#
#
# X
#
#
#
# P
#
#
#
#
#
# X
#
#
#
# P
#
#
#
# P
#
#
#
#
# X
#
#
#
#
#
#
#
# P
#
#
# P
#
#
#
#
#
#
#
#
#
# \
# ...

# %%
text= np.array(text)
print(text)
# Out:
# ['$' '\x16' 'P' ..., '\x17' '\x0b' '^']

# %%
# trying to generate word
data = np.genfromtxt('p059_cipher.txt', delimiter = ',')
i = 0
text = []
txt  = []
while i < len(data):
    if alpha[int(data[i]) != ' ':
        txt.append(alpha[int(data[i])])
        i = i + 1
    else:
        txt = str(txt)
        print(txt)
        txt = []
#     print(alpha[int(data[i])])
#     text.append(alpha[int(data[i])])
# Out:
#   File "<ipython-input-51-c3acff3b1abd>", line 9
#     i = i + 1
#     ^
# SyntaxError: invalid syntax
