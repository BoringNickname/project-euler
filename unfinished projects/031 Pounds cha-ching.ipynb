# %%
import numpy as np

# %%
a = 0
combos = 0
while h <= 200:
    b = 0
    while b <= 100:
        c = 0
        while c <= 40:
            d = 0
            while d <= 20:
                e = 0
                while e <= 10:
                    f = 0
                    while f <= 4:
                        g = 0
                        while g <= 2:
                            h = 0
                            while h <= 1:
                                if a*1 + b*2 + c*5 + d*10 + e*20 + f*50 + g*100 + h*200 == 200:
                                    combos += 1
                                    print('bingo')
                                h += 1
                            g += 1
                        f += 1
                    e += 1
                d += 1
            c += 1
        b += 1
    a += 1
# Out:
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# bingo
# ...
