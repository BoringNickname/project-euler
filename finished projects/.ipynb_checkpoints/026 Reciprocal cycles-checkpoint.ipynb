# %%
n = 1
num = 97
prec = 200
i = 0
dec = []
recs = []
while i < prec:
    while n < num:
        if n == 0:
            dec = []
            break
        n = n*10
        dec.append(0)
#         print(0)
    #     print(n)
#     print(n//num)
    dec.append(n//num)
    n = (n - (n//num)*num)*10
    if n in recs:
        print('pass')
        break
#     print(n, 'n')
    recs.append(n)
#     print(recs, 'recs')
    i+=1
print(dec)
print(len(dec))
# Out:
# pass
# [0, 0, 1, 0, 3, 0, 9, 2, 7, 8, 3, 5, 0, 5, 1, 5, 4, 6, 3, 9, 1, 7, 5, 2, 5, 7, 7, 3, 1, 9, 5, 8, 7, 6, 2, 8, 8, 6, 5, 9, 7, 9, 3, 8, 1, 4, 4, 3, 2, 9, 8, 9, 6, 9, 0, 7, 2, 1, 6, 4, 9, 4, 8, 4, 5, 3, 6, 0, 8, 2, 4, 7, 4, 2, 2, 6, 8, 0, 4, 1, 2, 3, 7, 1, 1, 3, 4, 0, 2, 0, 6, 1, 8, 5, 5, 6, 7, 0, 1]
# 99

# %%
a = np.linspace(1,10000,10000)
i = 0
best = 0
while i < len(a):
    if best < longlong(1, a[i]):
        best = longlong(1, a[i])
        print(a[i])
    i +=1
best
# Out:
# 1.0
# 3.0
# 7.0
# 13.0
# 17.0
# 19.0
# 23.0
# 29.0
# 47.0
# 59.0
# 61.0
# 97.0
# 109.0
# 113.0
# 131.0
# 149.0
# 167.0
# 179.0
# 181.0
# 193.0
# 223.0
# 229.0
# 233.0
# 257.0
# 263.0
# 269.0
# 289.0
# 313.0
# 337.0
# 361.0
# 367.0
# 379.0
# 383.0
# 389.0
# 419.0
# 433.0
# 461.0
# 487.0
# 491.0
# 499.0
# 503.0
# 509.0
# 541.0
# 571.0
# 577.0
# 593.0
# 619.0
# 647.0
# 659.0
# 701.0
# 709.0
# 727.0
# 743.0
# 811.0
# 821.0
# 823.0
# 857.0
# 863.0
# 887.0
# 937.0
# 941.0
# 953.0
# 971.0
# 977.0
# 983.0
# 1019.0
# 1021.0
# 1033.0
# 1051.0
# 1063.0
# 1069.0
# 1087.0
# 1091.0
# 1097.0
# 1103.0
# 1109.0
# 1153.0
# 1171.0
# 1181.0
# 1193.0
# 1217.0
# 1223.0
# 1229.0
# 1259.0
# 1291.0
# 1297.0
# 1301.0
# 1303.0
# 1327.0
# 1367.0
# 1381.0
# 1429.0
# 1433.0
# 1447.0
# 1487.0
# 1531.0
# 1543.0
# 1549.0
# 1553.0
# 1567.0
# 1571.0
# 1579.0
# 1583.0
# 1607.0
# 1619.0
# 1621.0
# 1663.0
# 1697.0
# 1709.0
# 1741.0
# 1777.0
# 1783.0
# 1789.0
# 1811.0
# 1823.0
# 1847.0
# 1861.0
# 1873.0
# 1913.0
# 1949.0
# ...

# %%
def longlong(n, num):
    
    prec = 1000000
    i = 0
    dec = []
    recs = []
    while i < prec:
        while n < num:
            if n == 0:
                dec = []
                break
            n = n*10
            dec.append(0)
    #         print(0)
        #     print(n)
    #     print(n//num)
        dec.append(n//num)
        n = (n - (n//num)*num)*10
        if n in recs:
#             print('pass')
            break
#         print(n, 'n')
        recs.append(n)
#         print(recs, 'recs')
        i+=1
#     print(dec)
#     print(len(dec))
    return len(dec)
