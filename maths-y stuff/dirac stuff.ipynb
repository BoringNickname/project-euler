# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(-10,10,1000)
plt.figure(figsize=(15,10))
plt.ylim(-1,1)
plt.plot(t, np.sin(10*t/(np.pi*t)))
plt.show()

# %%
np.sin(3*2/(np.pi*2))
# Out:
# 0.81627310858942137
