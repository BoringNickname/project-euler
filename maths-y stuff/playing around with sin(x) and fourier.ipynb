# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
np.exp(1)
# Out:
# 2.7182818284590451

# %%
a = np.linspace(-np.pi, 20*np.pi, 100000)
x = a*np.sin(1/a)**-1
plt.plot(a,x)
# plt.ylim([-10,10])
# plt.xlim([-1,1])
plt.grid()
plt.show()

# %%
def fs(n):
    i = 0
    t = np.linspace(-12,12,1000)
    while i < n:
        (2/np.pi*i)*(-1)**i*np.exp(np.pi*i*t)

# %%
plt.plot(a, np.sin(a))
# plt.xscale('log')
plt.yscale('log')
plt.show()
