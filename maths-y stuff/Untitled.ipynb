# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-np.pi, 10*np.pi, 500)

# %%
plt.plot(np.sin(x))
# plt.xscale('log')
plt.yscale('log')
# plt.xscale('log')
plt.show()

# %%
2**100
# Out:
# 1267650600228229401496703205376

# %%
len(str(2**1000000))
# Out:
# 301030

# %%
import matplotlib.pyplot as plt
import numpy as np
alpha = np.linspace(0.0001,15,50)
line = np.linspace(0,1,100)
line1 = 6+line*0
f= 1-(alpha+1)*np.exp(-alpha)
plt.plot(alpha, f)
# plt.plot(line1,line)
plt.show()
