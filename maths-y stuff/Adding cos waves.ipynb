# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sums = 0
f = np.linspace(1,100,1000)
T = 1/f
w = 2*np.pi/T
for i in f:
    sums = sums + np.sin(f[i])
sin = np.sin(f)
plt.plot(f, sin)
plt.xlim(0,100)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-12151f784ee1> in <module>()
#       4 w = 2*np.pi/T
#       5 for i in f:
# ----> 6     sums = sums + np.sin(f[i])
#       7 sin = np.sin(f)
#       8 plt.plot(f, sin)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
plt.plot(f, np.sin(f))
plt.show()
