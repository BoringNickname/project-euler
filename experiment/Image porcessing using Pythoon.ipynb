# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from astropy.io import fits
# importing all the necesary packages into jupyter
import scipy
from scipy import signal
from scipy import misc
import cv2

# %%
im = (np.array(Image.open('stars.jpg')))
plt.figure(figsize=(16,10))
plt.imshow(im)
plt.show()

# %%
fix = scipy.signal.convolve2d(im,[[0,1/4,0],[1/4,0,1/4],[0,1/4,0]], mode = 'same', boundary = 'wrap')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-be54ba9e7156> in <module>()
# ----> 1 fix = scipy.signal.convolve2d(im,[[0,1/4,0],[1/4,0,1/4],[0,1/4,0]], mode = 'same', boundary = 'wrap')
#
# /usr/lib64/python3.4/site-packages/scipy/signal/signaltools.py in convolve2d(in1, in2, mode, boundary, fillvalue)
#     700
#     701     if not in1.ndim == in2.ndim == 2:
# --> 702         raise ValueError('convolve2d inputs must both be 2D arrays')
#     703
#     704     if _inputs_swap_needed(mode, in1.shape, in2.shape):
#
# ValueError: convolve2d inputs must both be 2D arrays

# %%
import cv2
import numpy as np

#read image
src = cv2.imread('stars.jpg')
# print(src.shape)

# assign red channel to zeros
src[:,:,2] = np.zeros([src.shape[0], src.shape[1]])
cv2.imshow('stars',src)
# cv2.waitKey(0)
